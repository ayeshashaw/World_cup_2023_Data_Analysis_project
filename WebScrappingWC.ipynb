# %%
import pandas as pd
data2 = pd.read_html("https://www.espncricinfo.com/records/tournament/bowling-most-wickets-career/icc-cricket-world-cup-2023-24-15338")

print(type(data2))
print(len(data2))

# Access the DataFrame from the list
df=data2[0]
df.to_csv("icc_cricket_world_cup_2023_blowing_records.csv", index=False)
# Out:
# C:\Users\SUMAN\AppData\Local\Temp\ipykernel_21292\159812045.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# <class 'list'>
# 1
#                   Player       Span  Mat  Inns  Balls  Overs Mdns  Runs  Wkts  \
# 0   Mohammed Shami (IND)  2023-2023    7     7    293   48.5    4   257    24
# 1          A Zampa (AUS)  2023-2023   11    11    576   96.0    1   515    23
# 2      D Madushanka (SL)  2023-2023    9     9    470   78.2    4   525    21
# 3        JJ Bumrah (IND)  2023-2023   11    11    551   91.5    9   373    20
# ...

# %%
import pandas as pd

# Read the HTML table from the URL
data = pd.read_html("https://www.espncricinfo.com/records/tournament/batting-most-runs-career/icc-cricket-world-cup-2023-24-15338")

# Check the type of data and its length
print(type(data))
print(len(data))

# Access the DataFrame from the list
df = data[0]

# Save the DataFrame to a CSV file
df.to_csv("icc_cricket_world_cup_2023_24_batting_records.csv", index=False)
# Out:
# <class 'list'>
# 1

# %%
import pandas as pd
data1 = pd.read_html("https://www.careerpower.in/cricket-world-cup-winners-list.html")
print(type(data1))
print(len(data1))

# Access the DataFrame from the list
df=data1[0]
df.to_csv("icc_cricket_world_cup_2023_winning_records.csv", index=False)
# Out:
# <class 'list'>
# 2

# %%
import pandas as pd
data1 = pd.read_html("https://www.espncricinfo.com/records/tournament/team-match-results/icc-cricket-world-cup-2023-24-15338")
print(type(data1))
print(len(data1))

# Access the DataFrame from the list
df=data1[0]

df.to_csv("icc_cricket_world_cup_2023_24_records.csv", index=False)
# Out:
# <class 'list'>
# 1

# %%
import pandas as pd
data1 = pd.read_html("https://www.espncricinfo.com/records/tournament/team-match-results/icc-cricket-world-cup-2023-24-15338")
print(type(data1))
print(len(data1))

# Access the DataFrame from the list
df=data1[0]

df.to_csv("icc_cricket_world_cup_2023_24_records.csv", index=False)

# %%
import pandas as pd
Afganistan = pd.read_html("https://en.wikipedia.org/wiki/2023_Cricket_World_Cup_squads")



# Access the DataFrame from the list
df=pd.DataFrame(Afganistan[1])
df
# Out:
#     S/N                    Player          Date of birth (age)  ODIs  \
# 0    50  Hashmatullah Shahidi (c)    4 November 1994 (aged 28)    64
# 1    15                Noor Ahmad     3 January 2005 (aged 18)     3
# 2    46             Ikram Alikhil   28 November 2000 (aged 22)    14
# 3     5          Fazalhaq Farooqi  22 September 2000 (aged 23)    21
# 4    21   Rahmanullah Gurbaz (wk)   28 November 2001 (aged 21)    26
# 5    76               Riaz Hassan    7 November 2002 (aged 20)     5
# 6    19               Rashid Khan  20 September 1998 (aged 25)    94
# 7     7             Mohammad Nabi     1 January 1985 (aged 38)   147
# 8     9        Azmatullah Omarzai      24 March 2000 (aged 23)    13
# 9    27              Abdul Rahman   22 November 2001 (aged 21)     3
# 10    8               Rahmat Shah        6 July 1993 (aged 30)    97
# 11   78             Naveen-ul-Haq  23 September 1999 (aged 24)     7
# 12   88          Mujeeb Ur Rahman      28 March 2001 (aged 22)    66
# ...

# %%
import pandas as pd
Australia = pd.read_html("https://en.wikipedia.org/wiki/2023_Cricket_World_Cup_squads")



# Access the DataFrame from the list
df=pd.DataFrame(Australia[2])
df
# Out:
#     S/N              Player         Date of birth (age)  ODIs           Role  \
# 0    30     Pat Cummins (c)        8 May 1993 (aged 30)    77         Bowler
# 1    77         Sean Abbott  29 February 1992 (aged 31)    17         Bowler
# 2     4     Alex Carey (wk)    27 August 1991 (aged 32)    71  Wicket-keeper
# 3    42       Cameron Green       3 June 1999 (aged 24)    20    All-rounder
# 4    38      Josh Hazlewood    8 January 1991 (aged 32)    74         Bowler
# 5    62         Travis Head  29 December 1993 (aged 29)    58        Batsman
# 6    48    Josh Inglis (wk)      10 June 1995 (aged 28)     8  Wicket-keeper
# 7    33  Marnus Labuschagne       22 May 1994 (aged 29)    38    All-rounder
# 8     8      Mitchell Marsh   20 October 1991 (aged 31)    79    All-rounder
# 9    32       Glenn Maxwell   14 October 1988 (aged 34)   129    All-rounder
# 10   49         Steve Smith       2 June 1989 (aged 34)   145        Batsman
# ...

# %%
import pandas as pd
Bangladesh= pd.read_html("https://en.wikipedia.org/wiki/2023_Cricket_World_Cup_squads")


df=pd.DataFrame(Bangladesh[3])
df
# Out:
#     S/N                      Player         Date of birth (age)  ODIs  \
# 0    99  Najmul Hossain Shanto (vc)    25 August 1998 (aged 25)    30
# 1    10                 Nasum Ahmed   5 December 1994 (aged 28)    12
# 2     3                Taskin Ahmed      5 April 1995 (aged 28)    63
# 3    16                  Litton Das   13 October 1994 (aged 28)    77
# 4    66                Anamul Haque  16 December 1992 (aged 30)    38
# 5    21          Tanzim Hasan Sakib   20 October 2002 (aged 20)     2
# 6    97          Tanzid Hasan Tamim   1 December 2000 (aged 22)     5
# 7    77               Towhid Hridoy   4 December 2000 (aged 22)    17
# 8    55                Mahedi Hasan  12 December 1994 (aged 28)     8
# 9    53                Mehidy Hasan   25 October 1997 (aged 25)    82
# 10   47              Shoriful Islam       3 June 2001 (aged 22)    22
# 11   30                 Mahmudullah   4 February 1986 (aged 37)   221
# ...

# %%
import pandas as pd
England= pd.read_html("https://en.wikipedia.org/wiki/2023_Cricket_World_Cup_squads")


df=pd.DataFrame(England[4])
df
# Out:
#     S/N               Player          Date of birth (age)  ODIs  \
# 0    63  Jos Buttler (c, wk)   8 September 1990 (aged 33)   169
# 1    18       Moeen Ali (vc)        7 June 1987 (aged 36)   132
# 2    37         Gus Atkinson    19 January 1998 (aged 25)     3
# 3    51       Jonny Bairstow  26 September 1989 (aged 34)    98
# 4    88          Harry Brook   22 February 1999 (aged 24)     6
# 5    92         Brydon Carse       31 July 1995 (aged 28)    12
# 6    58           Sam Curran        3 June 1998 (aged 25)    26
# 7    23     Liam Livingstone      4 August 1993 (aged 30)    16
# 8    29          Dawid Malan   3 September 1987 (aged 36)    21
# 9    95          Adil Rashid   17 February 1988 (aged 35)   126
# 10   66             Joe Root   30 December 1990 (aged 32)   162
# 11   55           Ben Stokes        4 June 1991 (aged 32)   108
# 12   15         David Willey   28 February 1990 (aged 33)    67
# 13   19         Chris Woakes       2 March 1989 (aged 34)   114
# ...

# %%
import pandas as pd
India= pd.read_html("https://en.wikipedia.org/wiki/2023_Cricket_World_Cup_squads")


df=pd.DataFrame(India[5])
df
# Out:
#     S/N               Player          Date of birth (age)  ODIs  \
# 0    45     Rohit Sharma (c)      30 April 1987 (aged 36)   251
# 1    99  Ravichandran Ashwin  17 September 1986 (aged 37)   115
# 2    93       Jasprit Bumrah    6 December 1993 (aged 29)    78
# 3    77         Shubman Gill   8 September 1999 (aged 24)    35
# 4    96         Shreyas Iyer    6 December 1994 (aged 28)    47
# 5     8      Ravindra Jadeja    6 December 1988 (aged 34)   186
# 6    32    Ishan Kishan (wk)       18 July 1998 (aged 25)    25
# 7    18          Virat Kohli    5 November 1988 (aged 34)   281
# 8    24      Prasidh Krishna   19 February 1996 (aged 27)    17
# 9     1     K. L. Rahul (wk)      18 April 1992 (aged 31)    61
# 10   11       Mohammed Shami   3 September 1990 (aged 33)    94
# 11   73       Mohammed Siraj      13 March 1994 (aged 29)    30
# 12   54       Shardul Thakur   16 December 1991 (aged 31)    54
# 13   23        Kuldeep Yadav   11 December 1994 (aged 28)    89
# ...

# %%
import pandas as pd
Netherlands= pd.read_html("https://en.wikipedia.org/wiki/2023_Cricket_World_Cup_squads")


df=pd.DataFrame(Netherlands[6])
df
# Out:
#      S/N                 Player          Date of birth (age)  ODIs  \
# 0   35.0  Scott Edwards (c, wk)     23 August 1996 (aged 27)    38
# 1   48.0        Colin Ackermann       4 April 1991 (aged 32)     7
# 2   18.0           Shariz Ahmad      21 April 2003 (aged 20)    11
# 3   34.0         Wesley Barresi         3 May 1984 (aged 39)    45
# 4    5.0           Bas de Leede   15 November 1999 (aged 23)    30
# 5    NaN             Noah Croes   13 December 1999 (aged 23)     1
# 6   88.0             Aryan Dutt        12 May 2003 (aged 20)    25
# 7   72.0    Sybrand Engelbrecht  15 September 1988 (aged 35)     0
# 8   25.0        Teja Nidamanuru     22 August 1994 (aged 29)    20
# 9    4.0             Max O'Dowd       4 March 1994 (aged 29)    25
# 10   7.0        Vikramjit Singh     9 January 2003 (aged 20)    33
# 11  17.0         Logan van Beek   7 September 1990 (aged 33)    25
# 12  47.0      Paul van Meekeren    15 January 1993 (aged 30)    13
# ...

# %%
import pandas as pd
New_Zealand= pd.read_html("https://en.wikipedia.org/wiki/2023_Cricket_World_Cup_squads")


df=pd.DataFrame(New_Zealand[7])
df
# Out:
#     S/N               Player          Date of birth (age)  ODIs  \
# 0    22  Kane Williamson (c)      8 August 1990 (aged 33)   161
# 1    48  Tom Latham (vc, wk)       2 April 1992 (aged 31)   134
# 2    18          Trent Boult       22 July 1989 (aged 34)   104
# 3    80         Mark Chapman       27 June 1994 (aged 29)    12
# 4    88         Devon Conway        8 July 1991 (aged 32)    22
# 5    69      Lockie Ferguson       13 June 1991 (aged 32)    58
# 6    12        Kyle Jamieson   30 December 1994 (aged 28)    13
# 7    75       Daryl Mitchell        20 May 1991 (aged 32)    29
# 8    50        James Neesham  17 September 1990 (aged 33)    73
# 9    23       Glenn Phillips    6 December 1996 (aged 26)    20
# 10    8      Rachin Ravindra   18 November 1999 (aged 23)    12
# 11   74     Mitchell Santner    5 February 1992 (aged 31)    94
# 12   61            Ish Sodhi    31 October 1992 (aged 30)    49
# 13   38          Tim Southee   11 December 1988 (aged 34)   157
# ...

# %%
import pandas as pd
Pakistan= pd.read_html("https://en.wikipedia.org/wiki/2023_Cricket_World_Cup_squads")


df=pd.DataFrame(Pakistan[8])
df
# Out:
#     S/N                Player         Date of birth (age)  ODIs  \
# 0    56        Babar Azam (c)   15 October 1994 (aged 28)   108
# 1     7      Shadab Khan (vc)    4 October 1998 (aged 25)    64
# 2    10        Shaheen Afridi      6 April 2000 (aged 23)    44
# 3    95        Ifitkhar Ahmed  3 September 1990 (aged 33)    19
# 4    32             Hasan Ali   7 February 1994 (aged 29)    60
# 5    67       Salman Ali Agha  23 November 1993 (aged 29)    18
# 6    24             Usama Mir  23 December 1995 (aged 27)     8
# 7    21        Mohammad Nawaz     21 March 1994 (aged 29)    32
# 8    97            Haris Rauf   7 November 1993 (aged 29)    28
# 9    16  Mohammad Rizwan (wk)       1 June 1992 (aged 31)    65
# 10   57     Abdullah Shafique  23 November 1999 (aged 23)     4
# 11   59          Saud Shakeel  5 September 1995 (aged 28)     6
# 12   26           Imam-ul-Haq  12 December 1995 (aged 27)    66
# 13   74    Mohammad Wasim Jr.    25 August 2001 (aged 22)    16
# ...

# %%
import pandas as pd
South_Africa= pd.read_html("https://en.wikipedia.org/wiki/2023_Cricket_World_Cup_squads")


df=pd.DataFrame(South_Africa[9])
df
# Out:
#     S/N                 Player         Date of birth (age)  ODIs  \
# 0    11       Temba Bavuma (c)       17 May 1990 (aged 33)    28
# 1    16    Keshav Maharaj (vc)   7 February 1990 (aged 33)    31
# 2    62         Gerald Coetzee    2 October 2000 (aged 23)     6
# 3    12   Quinton de Kock (wk)  17 December 1992 (aged 30)   145
# 4    17        Reeza Hendricks    14 August 1989 (aged 34)    29
# 5    70           Marco Jansen        1 May 2000 (aged 23)    14
# 6    45  Heinrich Klaasen (wk)      30 July 1991 (aged 32)    41
# 7     4          Aiden Markram    4 October 1994 (aged 29)    55
# 8    10           David Miller      10 June 1989 (aged 34)   160
# 9    22            Lungi Ngidi     29 March 1996 (aged 27)    48
# 10   23     Andile Phehlukwayo      3 March 1996 (aged 27)    76
# 11   25          Kagiso Rabada       25 May 1995 (aged 28)    91
# 12   26         Tabraiz Shamsi  18 February 1990 (aged 33)    46
# ...

# %%
import pandas as pd
Srilanka= pd.read_html("https://en.wikipedia.org/wiki/2023_Cricket_World_Cup_squads")


df=pd.DataFrame(Srilanka[10])
df
# Out:
#     S/N                  Player          Date of birth (age)  ODIs  \
# 0    13   Kusal Mendis (vc, wk)    2 February 1995 (aged 28)   112
# 1    72        Charith Asalanka       29 June 1997 (aged 26)    41
# 2     5     Dushmantha Chameera    11 January 1992 (aged 31)    44
# 3    75     Dhananjaya de Silva   6 September 1991 (aged 32)    48
# 4    34         Dushan Hemantha        24 May 1994 (aged 29)     3
# 5    29     Chamika Karunaratne        29 May 1996 (aged 27)    23
# 6    16      Dimuth Karunaratne      21 April 1988 (aged 35)    48
# 7    98      Dilshan Madushanka  18 September 2000 (aged 23)     6
# 8    69          Angelo Mathews        2 June 1987 (aged 36)   221
# 9    18         Pathum Nissanka        18 May 1998 (aged 25)    40
# 10   55            Kusal Perera     17 August 1990 (aged 33)   109
# 11   65           Kasun Rajitha        1 June 1993 (aged 30)    28
# 12   23  Sadeera Samarawickrama       30 June 1995 (aged 28)    23
# ...

# %%
All_players=pd.concat([Afganistan[1],Australia[2],Bangladesh[3],England[4],India[5],Netherlands[6],New_Zealand[7],Pakistan[8],South_Africa[9],Srilanka[10]])
All_players
All_players.to_csv("icc_cricket_world_all_players_details.csv", index=False)
